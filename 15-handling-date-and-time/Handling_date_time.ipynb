# %%
import numpy as np
import pandas as pd

time = pd.read_csv("messages.csv")
date  = pd.read_csv("orders.csv")

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# #working with dates

# %%
date["date"] = pd.to_datetime(date["date"])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %% [markdown]
# #1.extract year

# %%
date["date_year"] = date["date"].dt.year
date.head()
# Out:
#         date  product_id  city_id  orders  date_year
# 0 2019-12-10        5628       25       3       2019
# 1 2018-08-15        3646       14     157       2018
# 2 2018-10-23        1859       25       1       2018
# 3 2019-08-17        7292       25       1       2019
# 4 2019-01-06        4344       25       3       2019

# %% [markdown]
# #2.extract month

# %%
date["date_month_no"] = date["date"].dt.month
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1

# %%
date["date_month_no"] = date["date"].dt.month_name()
date.head()
# Out:
#         date  product_id  city_id  orders  date_year date_month_no
# 0 2019-12-10        5628       25       3       2019      December
# 1 2018-08-15        3646       14     157       2018        August
# 2 2018-10-23        1859       25       1       2018       October
# 3 2019-08-17        7292       25       1       2019        August
# 4 2019-01-06        4344       25       3       2019       January

# %% [markdown]
# #3.extract day

# %%
date["date_day"] = date["date"].dt.day
date.head()
# Out:
#         date  product_id  city_id  orders  date_year date_month_no  date_day
# 0 2019-12-10        5628       25       3       2019      December        10
# 1 2018-08-15        3646       14     157       2018        August        15
# 2 2018-10-23        1859       25       1       2018       October        23
# 3 2019-08-17        7292       25       1       2019        August        17
# 4 2019-01-06        4344       25       3       2019       January         6

# %%
date["date_day"] = date["date"].dt.dayofweek
date.head()
# Out:
#         date  product_id  city_id  orders  date_year date_month_no  date_day
# 0 2019-12-10        5628       25       3       2019      December         1
# 1 2018-08-15        3646       14     157       2018        August         2
# 2 2018-10-23        1859       25       1       2018       October         1
# 3 2019-08-17        7292       25       1       2019        August         5
# 4 2019-01-06        4344       25       3       2019       January         6

# %%
date["date_day_name"] = date["date"].dt.day_name()
date.head()
# Out:
#         date  product_id  city_id  orders  date_year date_month_no  date_day  \
# 0 2019-12-10        5628       25       3       2019      December         1
# 1 2018-08-15        3646       14     157       2018        August         2
# 2 2018-10-23        1859       25       1       2018       October         1
# 3 2019-08-17        7292       25       1       2019        August         5
# 4 2019-01-06        4344       25       3       2019       January         6
#
#   date_day_name
# 0       Tuesday
# 1     Wednesday
# 2       Tuesday
# 3      Saturday
# 4        Sunday

# %%
# is weekend?

date['date_is_weekend'] = np.where(date['date_day_name'].isin(['Sunday', 'Saturday']), 1,0)

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year date_month_no  date_day date_day_name  date_is_weekend
# 0 2019-12-10       2019      December         1       Tuesday                0
# 1 2018-08-15       2018        August         2     Wednesday                0
# 2 2018-10-23       2018       October         1       Tuesday                0
# 3 2019-08-17       2019        August         5      Saturday                1
# 4 2019-01-06       2019       January         6        Sunday                1

# %% [markdown]
# #Extract week of the year

# %%
date['date_week'] = date['date'].dt.isocalendar().week

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year date_month_no  date_day date_day_name  \
# 0 2019-12-10       2019      December         1       Tuesday
# 1 2018-08-15       2018        August         2     Wednesday
# 2 2018-10-23       2018       October         1       Tuesday
# 3 2019-08-17       2019        August         5      Saturday
# 4 2019-01-06       2019       January         6        Sunday
#
#    date_is_weekend  date_week
# 0                0         50
# 1                0         33
# 2                0         43
# 3                1         33
# 4                1          1

# %% [markdown]
# #Extract Quarter

# %%
date['quarter'] = date['date'].dt.quarter

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year date_month_no  date_day date_day_name  \
# 0 2019-12-10       2019      December         1       Tuesday
# 1 2018-08-15       2018        August         2     Wednesday
# 2 2018-10-23       2018       October         1       Tuesday
# 3 2019-08-17       2019        August         5      Saturday
# 4 2019-01-06       2019       January         6        Sunday
#
#    date_is_weekend  date_week  quarter
# 0                0         50        4
# 1                0         33        3
# 2                0         43        4
# 3                1         33        3
# 4                1          1        1

# %% [markdown]
# #Extract Semester

# %%
date['semester'] = np.where(date['quarter'].isin([1,2]), 1, 2)

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year date_month_no  date_day date_day_name  \
# 0 2019-12-10       2019      December         1       Tuesday
# 1 2018-08-15       2018        August         2     Wednesday
# 2 2018-10-23       2018       October         1       Tuesday
# 3 2019-08-17       2019        August         5      Saturday
# 4 2019-01-06       2019       January         6        Sunday
#
#    date_is_weekend  date_week  quarter  semester
# 0                0         50        4         2
# 1                0         33        3         2
# 2                0         43        4         2
# 3                1         33        3         2
# 4                1          1        1         1

# %% [markdown]
# #Extract Time elapsed between dates

# %%
import datetime

today = datetime.datetime.today()

today
# Out:
# datetime.datetime(2026, 1, 7, 11, 42, 41, 348017)

# %%
today - date['date']
# Out:
# 0     2220 days 11:42:41.348017
# 1     2702 days 11:42:41.348017
# 2     2633 days 11:42:41.348017
# 3     2335 days 11:42:41.348017
# 4     2558 days 11:42:41.348017
#                  ...
# 995   2648 days 11:42:41.348017
# 996   2589 days 11:42:41.348017
# 997   2437 days 11:42:41.348017
# 998   2502 days 11:42:41.348017
# 999   2276 days 11:42:41.348017
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - date['date']).dt.days
# Out:
# 0      2220
# 1      2702
# 2      2633
# 3      2335
# 4      2558
#        ...
# 995    2648
# 996    2589
# 997    2437
# 998    2502
# 999    2276
# Name: date, Length: 1000, dtype: int64

# %%
# Converting to datetime datatype
time['date'] = pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time['hour'] = time['date'].dt.hour
time['min'] = time['date'].dt.minute
time['sec'] = time['date'].dt.second

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec
# 0     0   50    0
# 1    23   40    0
# 2     0   21    0
# 3     0   31    0
# 4    23   11    0

# %% [markdown]
# #Extract Time part

# %%
time['time'] = time['date'].dt.time

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec      time
# 0     0   50    0  00:50:00
# 1    23   40    0  23:40:00
# 2     0   21    0  00:21:00
# 3     0   31    0  00:31:00
# 4    23   11    0  23:11:00

# %% [markdown]
# #Time difference

# %%
today - time['date']
# Out:
# 0     4406 days 10:52:41.348017
# 1     4270 days 12:02:41.348017
# 2     4756 days 11:21:41.348017
# 3     4058 days 11:11:41.348017
# 4     4455 days 12:31:41.348017
#                  ...
# 995   5045 days 10:52:41.348017
# 996   4366 days 12:28:41.348017
# 997   4831 days 12:05:41.348017
# 998   4947 days 12:08:41.348017
# 999   4219 days 12:17:41.348017
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
# in seconds

(today - time['date'])/np.timedelta64(1,'s')
# Out:
# 0      3.807176e+08
# 1      3.689714e+08
# 2      4.109593e+08
# 3      3.506515e+08
# 4      3.849571e+08
#            ...
# 995    4.359272e+08
# 996    3.772673e+08
# 997    4.174419e+08
# 998    4.274645e+08
# 999    3.645659e+08
# Name: date, Length: 1000, dtype: float64

# %%
# in minutes

(today - time['date'])/np.timedelta64(1,'m')
# Out:
# 0      6.345293e+06
# 1      6.149523e+06
# 2      6.849322e+06
# 3      5.844192e+06
# 4      6.415952e+06
#            ...
# 995    7.265453e+06
# 996    6.287789e+06
# 997    6.957366e+06
# 998    7.124409e+06
# 999    6.076098e+06
# Name: date, Length: 1000, dtype: float64

# %%
# in hours

(today - time['date'])/np.timedelta64(1,'h')
# Out:
# 0      105754.878152
# 1      102492.044819
# 2      114155.361486
# 3       97403.194819
# 4      106932.528152
#            ...
# 995    121090.878152
# 996    104796.478152
# 997    115956.094819
# 998    118740.144819
# 999    101268.294819
# Name: date, Length: 1000, dtype: float64
